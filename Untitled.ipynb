# %%
from utils.custom_functions import read_pickled_File

# %%
gpu_dictf = '/home/rohit/Documents/Research/ICRA_2020/DDDAS_2D_Highway/DP/Trans_matxs_3D/GPU_testGrid_3_3D_20nT_a8/GPU_testGrid_3_3D_20nT_a8'
gpu_coof = '/home/rohit/Documents/Research/ICRA_2020/DDDAS_2D_Highway/DP/Trans_matxs_3D/GPU_testGrid_3_3D_20nT_a8/GPU_testGrid_3_3D_20nT_a8_COO'
gpu_rsaf = '/home/rohit/Documents/Research/ICRA_2020/DDDAS_2D_Highway/DP/Trans_matxs_3D/GPU_testGrid_3_3D_20nT_a8/GPU_testGrid_3_3D_20nT_a8_Rsa'
cpu_dictf = '/home/rohit/Documents/Research/ICRA_2020/DDDAS_2D_Highway/DP/Trans_matxs_3D/CPU_testGrid_3_8a/CPU_testGrid_3_8a'

# %%
gpu_tdict = read_pickled_File(gpu_dictf)
cpu_tdict = read_pickled_File(cpu_dictf)
gpu_coo = read_pickled_File(gpu_coof)
gpu_rsa = read_pickled_File(gpu_rsaf)
# Out:
# READING /home/rohit/Documents/Research/ICRA_2020/DDDAS_2D_Highway/DP/Trans_matxs_3D/GPU_testGrid_3_3D_20nT_a8/GPU_testGrid_3_3D_20nT_a8.p
# READING /home/rohit/Documents/Research/ICRA_2020/DDDAS_2D_Highway/DP/Trans_matxs_3D/CPU_testGrid_3_8a/CPU_testGrid_3_8a.p
# READING /home/rohit/Documents/Research/ICRA_2020/DDDAS_2D_Highway/DP/Trans_matxs_3D/GPU_testGrid_3_3D_20nT_a8/GPU_testGrid_3_3D_20nT_a8_COO.p
# READING /home/rohit/Documents/Research/ICRA_2020/DDDAS_2D_Highway/DP/Trans_matxs_3D/GPU_testGrid_3_3D_20nT_a8/GPU_testGrid_3_3D_20nT_a8_Rsa.p

# %%
gpu_tdict
# Out:
# {(0, 1, 1): {(1, 0.0): {(1, 1, 2): (1.0, -1.0)},
#   (1, 0.78539816339745): {(1, 0, 2): (1.0, -101.526184)},
#   (1, 1.5707963267949): {(1, 0, 1): (1.0, -101.22251)},
#   (1, 2.35619449019234): {(1, 1, 0): (1.0, -101.4339)},
#   (1, 3.14159265358979): {(1, 1, 0): (1.0, -101.4339)},
#   (1, 3.92699081698724): {(1, 2, 1): (1.0, -1.2225218)},
#   (1, 4.71238898038469): {(1, 2, 2): (1.0, -1.5261788)},
#   (1, 5.49778714378214): {(1, 1, 2): (1.0, -1.0000001)}},
#  (0, 1, 2): {(1, 0.0): {(1, 1, 3): (1.0, -1.0)},
#   (1, 0.78539816339745): {(1, 0, 3): (1.0, -101.526184)},
#   (1, 1.5707963267949): {(1, 0, 2): (1.0, -101.22251)},
#   (1, 2.35619449019234): {(1, 1, 1): (1.0, -1.4338837)},
#   (1, 3.14159265358979): {(1, 1, 1): (1.0, -1.433883)},
#   (1, 3.92699081698724): {(1, 2, 2): (1.0, -1.2225218)},
#   (1, 4.71238898038469): {(1, 2, 3): (1.0, -1.5261788)},
#   (1, 5.49778714378214): {(1, 1, 3): (1.0, -1.0000001)}},
#  (0, 1, 3): {(1, 0.0): {(1, 1, 4): (1.0, -1.0)},
# ...

# %%
cpu_tdict
# Out:
# {(0, 1, 1): {(1, 0.0): {(1, 1, 2): [1.0, -1.0]},
#   (1, 0.78539816339745): {(1, 0, 2): [1.0, -101.41421356237309]},
#   (1, 1.5707963267949): {(1, 0, 1): [1.0, -101.0]},
#   (1, 2.35619449019234): {(1, 0, 0): [1.0, -101.41421356237309]},
#   (1, 3.14159265358979): {(1, 1, 0): [1.0, -101.0]},
#   (1, 3.92699081698724): {(1, 2, 0): [1.0, -101.41421356237309]},
#   (1, 4.71238898038469): {(1, 2, 1): [1.0, -1.0]},
#   (1, 5.49778714378214): {(1, 2, 2): [1.0, -1.414213562373097]}},
#  (0, 1, 2): {(1, 0.0): {(1, 1, 3): [1.0, -1.0]},
#   (1, 0.78539816339745): {(1, 0, 3): [1.0, -101.41421356237309]},
#   (1, 1.5707963267949): {(1, 0, 2): [1.0, -101.0]},
#   (1, 2.35619449019234): {(1, 0, 1): [1.0, -101.41421356237309]},
#   (1, 3.14159265358979): {(1, 1, 1): [1.0, -1.0000000000000036]},
#   (1, 3.92699081698724): {(1, 2, 1): [1.0, -1.414213562373097]},
#   (1, 4.71238898038469): {(1, 2, 2): [1.0, -1.0]},
#   (1, 5.49778714378214): {(1, 2, 3): [1.0, -1.414213562373097]}},
# ...

# %%
from utils.setup_grid import setup_grid

g, xs, ys, X, Y, Vx_rzns, Vy_rzns, num_rzns, path_mat, params, param_str = setup_grid(num_actions =16, nt =3)
# Out:
# Grid Setup Complete !

# %%
ac_st_sp = g.ac_state_space()

# %%
ac_st_sp[-5:]
# Out:
# [(1, 98, 94), (1, 98, 95), (1, 98, 96), (1, 98, 97), (1, 98, 98)]
